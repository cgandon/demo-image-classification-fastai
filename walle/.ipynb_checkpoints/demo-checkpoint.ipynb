# %%
from fastai import *
from fastai.vision import *
from fastai.core import *

# %%
path = Path('imgs')

# %%
data = ImageDataBunch.from_folder(path, test='test', ds_tfms=get_transforms(), size=224)

# %%
data.show_batch(rows=3, figsize=(10,10))

# %%
learn = create_cnn(data, models.resnet34, metrics=accuracy)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:30 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.520718</th>
#     <th>0.056787</th>
#     <th>1.000000</th>
#   </tr>
# </table>

# %%
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)

# %%
interp.plot_top_losses(9, figsize=(10,10))

# %%
interp.plot_confusion_matrix()

# %%
preds,y = learn.get_preds(ds_type=DatasetType.Test)

# %%
#prints the order of the pictures to compare with the predictions array
data.test_dl.dl.x.items
# Out:
# array([PosixPath('imgs/test/doraemon.113.jpg'), PosixPath('imgs/test/doraemon.137.jpg'),
#        PosixPath('imgs/test/doraemon.123.jpg'), PosixPath('imgs/test/walle.137.jpg'),
#        PosixPath('imgs/test/walle.123.jpg'), PosixPath('imgs/test/walle.113.jpg')], dtype=object)

# %%
preds
# Out:
# tensor([[0.9601, 0.0399],
#         [0.9532, 0.0468],
#         [0.9818, 0.0182],
#         [0.1735, 0.8265],
#         [0.2077, 0.7923],
#         [0.6189, 0.3811]])

# %%
np.argmax(preds, axis=1)
# Out:
# tensor([0, 0, 0, 1, 1, 0])

# %%
learn.unfreeze()
learn.fit_one_cycle(3, slice(1e-5,3e-4))
# Out:
# Total time: 02:03 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.045292</th>
#     <th>0.053448</th>
#     <th>1.000000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.044225</th>
#     <th>0.027991</th>
#     <th>1.000000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.049237</th>
#     <th>0.019483</th>
#     <th>1.000000</th>
#   </tr>
# </table>

# %%
preds,y = learn.get_preds(ds_type=DatasetType.Test)

# %%
data.test_dl.dl.x.items
# Out:
# array([PosixPath('imgs/test/doraemon.113.jpg'), PosixPath('imgs/test/doraemon.137.jpg'),
#        PosixPath('imgs/test/doraemon.123.jpg'), PosixPath('imgs/test/walle.137.jpg'),
#        PosixPath('imgs/test/walle.123.jpg'), PosixPath('imgs/test/walle.113.jpg')], dtype=object)

# %%
np.argmax(preds, axis=1)
# Out:
# tensor([0, 0, 0, 1, 1, 1])
